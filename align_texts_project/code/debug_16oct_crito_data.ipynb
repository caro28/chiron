# %%
import pandas as pd

# %%
path_in = "~/repos/chiron/align_texts_project/data/crito/crito_el_translations_rawchunks_16Oct.json"

# %%
df = pd.read_json(path_in)

# %%
print(df.shape)
# Out:
# (268, 16)

# %%
df
# Out:
#               Sentence number  \
# 0       0059-003|1.|Cr.43a.1.
# 1       0059-003|2.|Cr.43a.2.
# 2       0059-003|3.|Cr.43a.3.
# 3       0059-003|4.|Cr.43a.4.
# 4       0059-003|5.|Cr.43a.5.
# ..                        ...
# 263  0059-003|263.|Cr. 54c.2.
# 264  0059-003|264.|Cr. 54c.3.
# 265  0059-003|265.|Cr. 54c.4.
# 266  0059-003|266.|Cr. 54d.1.
# 267  0059-003|267.|Cr. 54e.1.
#
#                                                  Greek  \
# 0              Σωκράτης. τί τηνικάδε ἀφῖξαι, ὦ Κρίτων;
# 1                                  ἢ οὐ πρῲ ἔτι ἐστίν;
# 2                                Κρίτων. πάνυ μὲν οὖν.
# 3                            Σωκράτης. πηνίκα μάλιστα;
# 4                                Κρίτων. ὄρθρος βαθύς.
# ..                                                 ...
# 263  ἀλλὰ μή σε πείσῃ Κρίτων ποιεῖν ἃ λέγει μᾶλλον ...
# 264  ἀλλὰ ἴσθι, ὅσα γε τὰ νῦν ἐμοὶ δοκοῦντα, ἐὰν λέ...
# 265       ὅμως μέντοι εἴ τι οἴει πλέον ποιήσειν, λέγε.
# ...
