# %%
import glob
import pandas as pd
import json
import os, sys
import subprocess

# %% [markdown]
# # Get perseus data df
# Copy of David's original Perseus dump here: /home/craig.car/repos/chiron/chironata/data/src_txts_perseus/

# %%
# out_path = "/scratch/craig.car/"
# for filepath in glob.iglob("/work/nulab/dasmith/cts/scaife/originals-translated-cts.jsonl/*.json"):
#     with open(filepath) as f:
#         for line in f:
#             row = json.loads(line)
#             with open(os.path.join(out_path, f"{row['id'].rsplit('.',1)[0]}.txt"), "w") as d:
#                 d.write(row['text'].replace('\n', ' '))
#             with open(os.path.join(out_path, f"{row['id'].rsplit('.',1)[0]}.json"), "w") as m:
#                 m.write(json.dumps(row['locs']))

# %%
# /scratch/craig.car/src_data/urn:cts:greekLit:tlg0005.tlg003.txt

for filepath in glob.iglob("/work/nulab/dasmith/cts/scaife/originals-translated-cts.jsonl/*.json"):
    with open(filepath) as f:
        for line in f:
            row = json.loads(line)
            # df = pd.json_normalize(row)
            # print(row["id"].split(".perseus-grc")[0])
            if row["id"].split(".perseus")[0] == "urn:cts:greekLit:tlg0237.tlg002":
                print(filepath)
            # with open(os.path.join(out_path, f"{row['id'].rsplit('.',1)[0]}.txt"), "w") as d:
            #     d.write(row['text'].replace('\n', ' '))
            # with open(os.path.join(out_path, f"{row['id'].rsplit('.',1)[0]}.json"), "w") as m:
            #     m.write(json.dumps(row['locs']))

# %%
theocritus_grk_path = "/work/nulab/dasmith/cts/scaife/originals-translated-cts.jsonl/part-00001-b62fdad1-2c28-4cf6-965f-7791072d1fc7-c000.json"
df = pd.read_json(
        path_or_buf=theocritus_grk_path,
        lines=True)
df
# Out:
#                                               id  \
# 0   urn:cts:greekLit:tlg0005.tlg002.perseus-grc2
# 1     urn:cts:greekLit:tlg0005.tlg003.1st1K-grc1
# 2   urn:cts:greekLit:tlg0006.tlg001.perseus-grc2
# 3   urn:cts:greekLit:tlg0006.tlg002.perseus-grc2
# 4   urn:cts:greekLit:tlg0006.tlg003.perseus-grc2
# 5   urn:cts:greekLit:tlg0006.tlg004.perseus-grc2
# 6   urn:cts:greekLit:tlg0006.tlg005.perseus-grc2
# 7   urn:cts:greekLit:tlg0006.tlg006.perseus-grc2
# 8   urn:cts:greekLit:tlg0006.tlg007.perseus-grc2
# 9   urn:cts:greekLit:tlg0006.tlg008.perseus-grc2
# 10  urn:cts:greekLit:tlg0006.tlg009.perseus-grc2
# 11  urn:cts:greekLit:tlg0006.tlg010.perseus-grc2
# 12  urn:cts:greekLit:tlg0006.tlg011.perseus-grc2
# 13  urn:cts:greekLit:tlg0006.tlg012.perseus-grc2
# 14  urn:cts:greekLit:tlg0006.tlg013.perseus-grc2
# 15  urn:cts:greekLit:tlg0006.tlg014.perseus-grc2
#
#                                                  text  \
# 0   τὰ ῥόδα τὰ δροσόεντα καὶ ἁ κατάπυκνος ἐκείνα\n...
# 1   Οὐδενὸς εὐνάτειρα Μακροπτολέμοιο δὲ μάτηρ\nμαί...
# 2   \nὮ Βρόμιε, διὰ σὲ μυρίους ἔχω πόνους\nνῦν χὥτ...
# 3   \nὮ δώματ’ Ἀδμήτειʼ, ἐν οἷς ἔτλην ἐγὼ\nθῆσσαν ...
# 4   \nΕἴθ’ ὤφελ’ Ἀργοῦς μὴ διαπτάσθαι σκάφος\nΚόλχ...
# 5   \nΠάλαι ποτʼ ἐστὶ τοῦτʼ ἐμοὶ δεδογμένον·\nὁ μὲ...
# 6   \nΠολλὴ μὲν ἐν βροτοῖσι κοὐκ ἀνώνυμος,\nθεὰ κέ...
# 7   \nἈσιάτιδος γῆς σχῆμα, Θηβαία πόλι,\nὅθεν ποθ’...
# 8   \nἭκω νεκρῶν κευθμῶνα καὶ σκότου πύλας\nλιπών,...
# 9   \nΔήμητερ ἑστιοῦχʼ Ἐλευσῖνος χθονὸς\nτῆσδʼ, οἵ...
# 10  \nΤίς τὸν Διὸς σύλλεκτρον οὐκ οἶδεν βροτῶν,\nἈ...
# 11  \nἌτλας, ὁ χαλκέοισι νώτοις οὐρανὸν\nθεῶν παλα...
# 12  \nἭκω λιπὼν Αἴγαιον ἁλμυρὸν βάθος\nπόντου Ποσε...
# 13  \nὦ γῆς παλαιὸν ἄργος, Ἰνάχου ῥοαί,\nὅθεν ποτʼ...
# 14  \nΠέλοψ ὁ Ταντάλειος ἐς Πῖσαν μολὼν\nθοαῖσιν ἵ...
# 15  \nΝείλου μὲν αἵδε καλλιπάρθενοι ῥοαί,\nὃς ἀντὶ...
#
#                                                  locs
# 0   [{'loc': 'urn:cts:greekLit:tlg0005.tlg002:1.1'...
# 1   [{'loc': 'urn:cts:greekLit:tlg0005.tlg003:1', ...
# 2   [{'loc': 'urn:cts:greekLit:tlg0006.tlg001:0', ...
# 3   [{'loc': 'urn:cts:greekLit:tlg0006.tlg002:0', ...
# 4   [{'loc': 'urn:cts:greekLit:tlg0006.tlg003:0', ...
# 5   [{'loc': 'urn:cts:greekLit:tlg0006.tlg004:0', ...
# 6   [{'loc': 'urn:cts:greekLit:tlg0006.tlg005:0', ...
# 7   [{'loc': 'urn:cts:greekLit:tlg0006.tlg006:0', ...
# 8   [{'loc': 'urn:cts:greekLit:tlg0006.tlg007:0', ...
# 9   [{'loc': 'urn:cts:greekLit:tlg0006.tlg008:0', ...
# 10  [{'loc': 'urn:cts:greekLit:tlg0006.tlg009:0', ...
# 11  [{'loc': 'urn:cts:greekLit:tlg0006.tlg010:0', ...
# 12  [{'loc': 'urn:cts:greekLit:tlg0006.tlg011:0', ...
# 13  [{'loc': 'urn:cts:greekLit:tlg0006.tlg012:0', ...
# 14  [{'loc': 'urn:cts:greekLit:tlg0006.tlg013:0', ...
# 15  [{'loc': 'urn:cts:greekLit:tlg0006.tlg014:0', ...

# %%
df.loc[1,'text']
# Out:
# slurm_run = 'srun --time 1-0 -p {QUEUE} -N 1 -c {SWORKERS} --mem={SMEM}G bash -c {command}'

# labse_run = 'srun --time 1-0 -p {QUEUE} -N 1 -c {SWORKERS} --mem={SMEM}G bash -c "source /home/craig.car/miniconda3/bin/activate; conda activate labse_vec_pipeline; {command};'

for path in glob.iglob("/scratch/craig.car/src_data/*.txt"):
    prefix = os.path.splitext(os.path.basename(path))[0]
    params['command'] = f'./segment_sents.py {path}'
    print(slurm_run.format(**params))
    subprocess.run(slurm_run.format(**params),shell=True)
    break
# Out:
# srun --time 1-0 -p short -N 1 -c 2 --mem=4G bash -c "source /home/craig.car/miniconda3/bin/activate; conda activate use_lxml; ./segment_sents.py /scratch/craig.car/src_data/urn:cts:greekLit:tlg0001.tlg001.txt";
# slurmstepd: error: execve(): bash: No such file or directory
# srun: error: c2201: task 0: Exited with exit code 2

# %%
srun --time 1-0 -p short -N 1 -c 2 --mem=1G bash -c ./segment_sents.py /scratch/craig.car/src_data/urn:cts:greekLit:tlg0001.tlg001.txt

# %%
test.iloc[0]['text'].replace('\n', ' ')
# Out:
# 'ἀρχόμενος σέο, Φοῖβε, παλαιγενέων κλέα φωτῶν μνήσομαι, οἳ Πόντοιο κατὰ στόμα καὶ διὰ πέτρας Κυανέας βασιλῆος ἐφημοσύνῃ Πελίαο χρύσειον μετὰ κῶας ἐύζυγον ἤλασαν Ἀργώ. τοίην γὰρ Πελίης φάτιν ἔκλυεν, ὥς μιν ὀπίσσω μοῖρα μένει στυγερή, τοῦδʼ ἀνέρος, ὅντινʼ ἴδοιτο δημόθεν οἰοπέδιλον, ὑπʼ ἐννεσίῃσι δαμῆναι. δηρὸν δʼ οὐ μετέπειτα τεὴν κατὰ βάξιν Ἰήσων χειμερίοιο ῥέεθρα κιὼν διὰ ποσσὶν Ἀναύρου ἄλλο μὲν ἐξεσάωσεν ὑπʼ ἰλύος, ἄλλο δʼ ἔνερθεν κάλλιπεν αὖθι πέδιλον ἐνισχόμενον προχοῇσιν. ἵκετο δʼ ἐς Πελίην αὐτοσχεδὸν ἀντιβολήσων εἰλαπίνης, ἣν πατρὶ Ποσειδάωνι καὶ ἄλλοις ῥέζε θεοῖς, Ἥρης δὲ Πελασγίδος οὐκ ἀλέγιζεν. αἶψα δὲ τόνγʼ ἐσιδὼν ἐφράσσατο, καί οἱ ἄεθλον ἔντυε ναυτιλίης πολυκηδέος, ὄφρʼ ἐνὶ πόντῳ ἠὲ καὶ ἀλλοδαποῖσι μετʼ ἀνδράσι νόστον ὀλέσσῃ. νῆα μὲν οὖν οἱ πρόσθεν ἐπικλείουσιν ἀοιδοὶ Ἄργον Ἀθηναίης καμέειν ὑποθημοσύνῃσιν. νῦν δʼ ἂν ἐγὼ γενεήν τε καὶ οὔνομα μυθησαίμην ἡρώων, δολιχῆς τε πόρους ἁλός, ὅσσα τʼ ἔρεξαν πλαζόμενοι· Μοῦσαι δʼ ὑποφήτορες εἶεν ἀοιδῆς. πρ�
path2 = "/work/nulab/dasmith/cts/scaife/originals-translated-cts.jsonl/part-00048-b62fdad1-2c28-4cf6-965f-7791072d1fc7-c000.json"
test2 = pd.read_json(
        path_or_buf=path2,
        lines=True)
test2
# Out:
#                                                 id  \
# 0       urn:cts:latinLit:stoa0058.stoa001.opp-lat3
# 1   urn:cts:latinLit:stoa0058.stoa001.perseus-lat2
# 2   urn:cts:latinLit:stoa0089.stoa001.perseus-lat2
# 3   urn:cts:latinLit:stoa0089.stoa002.perseus-lat2
# 4   urn:cts:latinLit:stoa0089.stoa003.perseus-lat2
# 5   urn:cts:latinLit:stoa0089.stoa004.perseus-lat2
# 6   urn:cts:latinLit:stoa0089.stoa005.perseus-lat2
# 7   urn:cts:latinLit:stoa0089.stoa006.perseus-lat2
# 8   urn:cts:latinLit:stoa0089.stoa007.perseus-lat2
# 9   urn:cts:latinLit:stoa0089.stoa008.perseus-lat2
# 10  urn:cts:latinLit:stoa0089.stoa009.perseus-lat2
# 11  urn:cts:latinLit:stoa0089.stoa010.perseus-lat2
# 12  urn:cts:latinLit:stoa0089.stoa011.perseus-lat2
# 13  urn:cts:latinLit:stoa0089.stoa012.perseus-lat2
# 14  urn:cts:latinLit:stoa0089.stoa013.perseus-lat2
# 15  urn:cts:latinLit:stoa0089.stoa014.perseus-lat2
# 16     urn:cts:latinLit:stoa0215c.stoa001.opp-lat1
# 17  urn:cts:latinLit:stoa0255.stoa004.perseus-lat2
# 18  urn:cts:latinLit:stoa0255.stoa006.perseus-lat2
# 19  urn:cts:latinLit:stoa0255.stoa007.perseus-lat2
# 20  urn:cts:latinLit:stoa0255.stoa008.perseus-lat2
# 21  urn:cts:latinLit:stoa0255.stoa009.perseus-lat2
# 22  urn:cts:latinLit:stoa0255.stoa010.perseus-lat2
# 23  urn:cts:latinLit:stoa0255.stoa011.perseus-lat2
# 24  urn:cts:latinLit:stoa0255.stoa012.perseus-lat2
# 25  urn:cts:latinLit:stoa0255.stoa013.perseus-lat2
# 26  urn:cts:latinLit:stoa0255.stoa014.perseus-lat2
#
#                                                  text  \
# 0   Carmina qui quondam studio florente peregi,\nf...
# 1   Carmina qui quondam studio florente peregi,Fle...
# 2   Solitas galea fulgere comas,\nStilicho, molli ...
# 3   Redditus imperiis Auster subiectaque rursus\na...
# 4   Post resides annos longo velut excita somno\nR...
# 5   Continuant superi pleno Romana favore\ngaudia ...
# 6   Inventa secuit primus qui nave profundum\net r...
# 7   Surgeret in thalamum ducto cum Pelion areu\nne...
# 8   princeps corusco sidere pulclirior,\nParthis s...
# 9   Semiferos partus metuendaque pignora matri\nmo...
# 10  Phoebeo domitus Python cum decidit arcu\nmembr...
# 11  Parvos non aquilis fas est educere fetus\nante...
# 12  Auspiciis iterum sese regalibus annus\ninduit ...
# 13  Omnia, quae sensu volvuntur vota diurno,\npect...
# 14  Audebisne, precor, tantae subiecta catervae,\n...
# 15  Sol, qui flammigeris mundum complexus habenis\...
# 16  Praeceptis tuis parui, beatissime pater August...
# 17  Maior pars mortalium, Pauline, de naturae\nmal...
# 18  Saepe iam, mater optima, impetum cepi consolan...
# 19  Nisi te, Marcia, scirem tam longe ab infirmita...
# 20  Urbes ac monumenta saxo structa, si vitae\nnos...
# 21  Tantum inter Stoicos, Serene, et ceteros sapie...
# 22  Exegisti a me. Novate, ut scriberem quemadmodu...
# 23  cit, nobis magno consensu vitia\ncommendant. L...
# 24  Quaesisti a me, Lucili, quid ita, si provident...
# 25  SERENUS : Inquirenti mihi in me quaedam\nvitia...
# 26  Vivere, Gallio frater, omnes beate volunt, sed...
#
#                                                  locs
# 0   [{'loc': 'urn:cts:latinLit:stoa0058.stoa001:1....
# 1   [{'loc': 'urn:cts:latinLit:stoa0058.stoa001:1....
# 2   [{'loc': 'urn:cts:latinLit:stoa0089.stoa001:1....
# 3   [{'loc': 'urn:cts:latinLit:stoa0089.stoa002:1'...
# 4   [{'loc': 'urn:cts:latinLit:stoa0089.stoa003:pr...
# 5   [{'loc': 'urn:cts:latinLit:stoa0089.stoa004:1....
# 6   [{'loc': 'urn:cts:latinLit:stoa0089.stoa005:1....
# 7   [{'loc': 'urn:cts:latinLit:stoa0089.stoa006:pr...
# 8   [{'loc': 'urn:cts:latinLit:stoa0089.stoa007:1....
# 9   [{'loc': 'urn:cts:latinLit:stoa0089.stoa008:1....
# 10  [{'loc': 'urn:cts:latinLit:stoa0089.stoa009:1....
# 11  [{'loc': 'urn:cts:latinLit:stoa0089.stoa010:pr...
# 12  [{'loc': 'urn:cts:latinLit:stoa0089.stoa011:1'...
# 13  [{'loc': 'urn:cts:latinLit:stoa0089.stoa012:pr...
# 14  [{'loc': 'urn:cts:latinLit:stoa0089.stoa013:pr...
# 15  [{'loc': 'urn:cts:latinLit:stoa0089.stoa014:1'...
# 16  [{'loc': 'urn:cts:latinLit:stoa0215c.stoa001:1...
# 17  [{'loc': 'urn:cts:latinLit:stoa0255.stoa004:1....
# 18  [{'loc': 'urn:cts:latinLit:stoa0255.stoa006:1....
# 19  [{'loc': 'urn:cts:latinLit:stoa0255.stoa007:1....
# 20  [{'loc': 'urn:cts:latinLit:stoa0255.stoa008:1....
# 21  [{'loc': 'urn:cts:latinLit:stoa0255.stoa009:1....
# 22  [{'loc': 'urn:cts:latinLit:stoa0255.stoa010:1....
# 23  [{'loc': 'urn:cts:latinLit:stoa0255.stoa011:1....
# 24  [{'loc': 'urn:cts:latinLit:stoa0255.stoa012:1....
# 25  [{'loc': 'urn:cts:latinLit:stoa0255.stoa013:1....
# 26  [{'loc': 'urn:cts:latinLit:stoa0255.stoa014:1....

# %%
pd.concat([test,test2],axis=0,ignore_index=True).loc[0,"text"]
# Out:
τος ἦεν Ὀιλεύς,\nἔξοχος ἠνορέην καὶ ἐπαΐξαι μετόπισθεν\nεὖ δεδαὼς δῄοισιν, ὅτε κλίνωσι φάλαγγας.\nαὐτὰρ ἀπʼ Εὐβοίης Κάνθος κίε, τόν ῥα Κάνηθος\nπέμπεν Ἀβαντιάδης λελιημένον· οὐ μὲν ἔμελλεν\nνοστήσειν Κήρινθον ὑπότροπος. αισα γὰρ ἦεν\nαὐτὸν ὁμῶς Μόψον τε δαήμονα μαντοσυνάων\nπλαγχθέντας Λιβύης ἐνὶ πείρασι δῃωθῆναι,\nὡς οὐκ ἀνθρώποισι κακὸν μήκιστον ἐπαυρεῖν,\nὁππότε κἀκείνους Λιβύῃ ἔνι ταρχύσαντο,\nτόσσον ἑκὰς Κόλχων, ὅσσον τέ περ ἠελίοιο\nμεσσηγὺς δύσιές τε καὶ ἀντολαὶ εἰσορόωνται.\nτῷ δʼ ἄρʼ ἐπὶ Κλυτίος τε καὶ Ἴφιτος\nἠγερέθοντο,\nΟἰχαλίης ἐπίουροι, ἀπηνέος Εὐρύτου υἷες,\nΕὐρύτου, ᾧ πόρε τόξον Ἑκηβόλος· οὐδʼ ἀπόνητο\nδωτίνης· αὐτῷ γὰρ ἑκὼν ἐρίδηνε δοτῆρι.\nτοῖσι δʼ ἐπʼ Αἰακίδαι μετεκίαθον· οὐ μὲν\nἅμʼ ἄμφω,\nοὐδʼ ὁμόθεν· νόσφιν γὰρ ἀλευάμενοι κατένασθεν\nΑἰγίνης, ὅτ ...

# %%
perseus_df = pd.DataFrame(columns=["id","text","locs"])

# %%
perseus_df
# Out:
# Empty DataFrame
# Columns: [id, text, locs]
# Index: []

# %%
for filepath in glob.iglob("/work/nulab/dasmith/cts/scaife/originals-translated-cts.jsonl/*.json"):
    df = pd.read_json(path_or_buf=filepath,lines=True)
    print(filepath)
    perseus_df.merge(df,how="inner")
# Out:
# /work/nulab/dasmith/cts/scaife/originals-translated-cts.jsonl/part-00000-b62fdad1-2c28-4cf6-965f-7791072d1fc7-c000.json
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_34263/2559477462.py in <module>
#       2     df = pd.read_json(path_or_buf=filepath,lines=True)
#       3     print(filepath)
# ----> 4     perseus_df.merge(df,how="inner")
#
# ~/miniconda3/envs/use_laser2/lib/python3.7/site-packages/pandas/core/frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    9201             copy=copy,
#    9202             indicator=indicator,
# -> 9203             validate=validate,
#    9204         )
#    9205
#
# ~/miniconda3/envs/use_laser2/lib/python3.7/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     119         validate=validate,
#     120     )
# --> 121     return op.get_result()
#     122
#     123
#
# ~/miniconda3/envs/use_laser2/lib/python3.7/site-packages/pandas/core/reshape/merge.py in get_result(self)
#     713             self.left, self.right = self._indicator_pre_merge(self.left, self.right)
#     714
# --> 715         join_index, left_indexer, right_indexer = self._get_join_info()
#     716
#     717         llabels, rlabels = _items_overlap_with_suffix(
#
# ~/miniconda3/envs/use_laser2/lib/python3.7/site-packages/pandas/core/reshape/merge.py in _get_join_info(self)
#     964             )
#     965         else:
# --> 966             (left_indexer, right_indexer) = self._get_join_indexers()
#     967
#     968             if self.right_index:
#
# ~/miniconda3/envs/use_laser2/lib/python3.7/site-packages/pandas/core/reshape/merge.py in _get_join_indexers(self)
#     939         # Both returned ndarrays are np.intp
#     940         return get_join_indexers(
# --> 941             self.left_join_keys, self.right_join_keys, sort=self.sort, how=self.how
#     942         )
#     943
#
# ~/miniconda3/envs/use_laser2/lib/python3.7/site-packages/pandas/core/reshape/merge.py in get_join_indexers(left_keys, right_keys, sort, how, **kwargs)
#    1479         for n in range(len(left_keys))
#    1480     )
# -> 1481     zipped = zip(*mapped)
#    1482     llab, rlab, shape = (list(x) for x in zipped)
#    1483
#
# ~/miniconda3/envs/use_laser2/lib/python3.7/site-packages/pandas/core/reshape/merge.py in <genexpr>(.0)
#    1477     mapped = (
#    1478         _factorize_keys(left_keys[n], right_keys[n], sort=sort, how=how)
# -> 1479         for n in range(len(left_keys))
#    1480     )
#    1481     zipped = zip(*mapped)
#
# ~/miniconda3/envs/use_laser2/lib/python3.7/site-packages/pandas/core/reshape/merge.py in _factorize_keys(lk, rk, sort, how)
#    2185
#    2186     llab = rizer.factorize(lk)
# -> 2187     rlab = rizer.factorize(rk)
#    2188     assert llab.dtype == np.intp, llab.dtype
#    2189     assert rlab.dtype == np.intp, rlab.dtype
#
# ~/miniconda3/envs/use_laser2/lib/python3.7/site-packages/pandas/_libs/hashtable.pyx in pandas._libs.hashtable.ObjectFactorizer.factorize()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_labels()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable._unique()
#
# TypeError: unhashable type: 'list'

# %%
# path = "/home/craig.car/repos/chiron/align_texts_project/data/david_perseus_datadump_cts-sections.jsonl.gz"
# perseus_df = pd.read_json(
#         path,
#         lines=True,
#         compression='gzip')

# %%
perseus_df.shape
# Out:
# (16, 3)

# %%
perseus_df.groupby("work").count()
# Out:
#                                   book     id    loc    seq   text  cites  \
# work
# urn:cts:greekLit:tlg0003.tlg001  14314  14314  14314  14314  14314  14314
# urn:cts:greekLit:tlg0007.tlg001    264    264    264    264    264    264
# urn:cts:greekLit:tlg0007.tlg002    322    322    322    322    322    322
# urn:cts:greekLit:tlg0007.tlg003     36     36     36     36     36     36
# urn:cts:greekLit:tlg0007.tlg004    306    306    306    306    306    306
# ...                                ...    ...    ...    ...    ...    ...
# urn:cts:greekLit:tlg1271.tlg002    236    236    236    236    236    236
# urn:cts:greekLit:tlg1419.tlg001   1454   1454   1454   1454   1454   1454
# urn:cts:greekLit:tlg2038.tlg001    341    341    341    341    341    341
# urn:cts:greekLit:tlg2948.tlg001    293    293    293    293    293    293
# urn:cts:greekLit:tlg4037.tlg001     46     46     46     46     46     46
#
#                                  group   lang  title  translation  wlang
# work
# urn:cts:greekLit:tlg0003.tlg001  14314  14314  14314        14314  14314
# urn:cts:greekLit:tlg0007.tlg001    264    264    264          264    264
# urn:cts:greekLit:tlg0007.tlg002    322    322    322          322    322
# urn:cts:greekLit:tlg0007.tlg003     36     36     36           36     36
# urn:cts:greekLit:tlg0007.tlg004    306    306    306          306    306
# ...                                ...    ...    ...          ...    ...
# urn:cts:greekLit:tlg1271.tlg002    236    236    236          236    236
# urn:cts:greekLit:tlg1419.tlg001   1454   1454   1454         1454   1454
# urn:cts:greekLit:tlg2038.tlg001    341    341    341          341    341
# urn:cts:greekLit:tlg2948.tlg001    293    293    293          293    293
# urn:cts:greekLit:tlg4037.tlg001     46     46     46           46     46
#
# [256 rows x 11 columns]

# %%
perseus_df.groupby("group").count()
# Out:
#                                     book     id    loc    seq   text  cites  \
# group
# Acta Philippi                        293    293    293    293    293    293
# Acta Thomae                          341    341    341    341    341    341
# Agathemerus                          234    234    234    234    234    234
# Anonymi Paradoxographi                46     46     46     46     46     46
# Appianus of Alexandria              2334   2334   2334   2334   2334   2334
# Clemens Romanus (Clement of Rome)   1036   1036   1036   1036   1036   1036
# Demosthenes                         8930   8930   8930   8930   8930   8930
# Hermas, 2nd cent.                   1454   1454   1454   1454   1454   1454
# Herodotus                           8676   8676   8676   8676   8676   8676
# Isocrates                           4008   4008   4008   4008   4008   4008
# Plato                               1340   1340   1340   1340   1340   1340
# Plutarch                           27756  27756  27756  27756  27755  27756
# Thucydides                         14314  14314  14314  14314  14314  14314
# Xenophon                           12546  12546  12546  12546  12545  12546
#
#                                     lang  title  translation  wlang   work
# group
# Acta Philippi                        293    293          293    293    293
# Acta Thomae                          341    341          341    341    341
# Agathemerus                          234    234          234    234    234
# Anonymi Paradoxographi                46     46           46     46     46
# Appianus of Alexandria              2334   2334         2334   2334   2334
# Clemens Romanus (Clement of Rome)   1036   1036         1036   1036   1036
# Demosthenes                         8930   8930         8930   8930   8930
# Hermas, 2nd cent.                   1454   1454         1454   1454   1454
# Herodotus                           8676   8676         8676   8676   8676
# Isocrates                           4008   4008         4008   4008   4008
# Plato                               1340   1340         1340   1340   1340
# Plutarch                           27756  27756        27756  27756  27756
# Thucydides                         14314  14314        14314  14314  14314
# Xenophon                           12546  12546        12546  12546  12546

# %% [markdown]
# # Get Plato works

# %%
plato = perseus_df.loc[perseus_df["group"]=="Plato"]

# %%
plato.groupby("work").count()
# Out:
#                                  book   id  loc  seq  text  cites  group  \
# work
# urn:cts:greekLit:tlg0059.tlg030   556  556  556  556   556    556    556
# urn:cts:greekLit:tlg0059.tlg034   654  654  654  654   654    654    654
# urn:cts:greekLit:tlg0059.tlg036   130  130  130  130   130    130    130
#
#                                  lang  title  translation  wlang
# work
# urn:cts:greekLit:tlg0059.tlg030   556    556          556    556
# urn:cts:greekLit:tlg0059.tlg034   654    654          654    654
# urn:cts:greekLit:tlg0059.tlg036   130    130          130    130

# %%
perseus_df.loc[perseus_df["work"]=="urn:cts:greekLit:tlg0059.tlg030"].head(1)
# Out:
#                                                book  \
# 76230  urn:cts:greekLit:tlg0059.tlg030.perseus-grc2
#
#                                                       id  \
# 76230  urn:cts:greekLit:tlg0059.tlg030.perseus-grc2:1...
#
#                                          loc  seq  \
# 76230  urn:cts:greekLit:tlg0059.tlg030:1.327    0
#
#                                                     text            cites  \
# 76230  κατέβην χθὲς εἰς Πειραιᾶ μετὰ Γλαύκωνος τοῦ Ἀρ...  [book, section]
#
#        group lang     title  translation wlang  \
# 76230  Plato  grc  Republic        False   grc
#
#                                   work
# 76230  urn:cts:greekLit:tlg0059.tlg030

# %%
perseus_df.loc[perseus_df["work"]=="urn:cts:greekLit:tlg0059.tlg034"].head(1)
# Out:
#                                                book  \
# 76786  urn:cts:greekLit:tlg0059.tlg034.perseus-grc2
#
#                                                       id  \
# 76786  urn:cts:greekLit:tlg0059.tlg034.perseus-grc2:1...
#
#                                          loc  seq  \
# 76786  urn:cts:greekLit:tlg0059.tlg034:1.624    0
#
#                                                     text            cites  \
# 76786  ΑΘ. θεὸς ἤ τις ἀνθρώπων ὑμῖν, ὦ ξένοι, εἴληφε ...  [book, section]
#
#        group lang title  translation wlang                             work
# 76786  Plato  grc  Laws        False   grc  urn:cts:greekLit:tlg0059.tlg034

# %%
perseus_df.loc[perseus_df["work"]=="urn:cts:greekLit:tlg0059.tlg036"].head(1)
# Out:
#                                                book  \
# 77440  urn:cts:greekLit:tlg0059.tlg036.perseus-grc2
#
#                                                       id  \
# 77440  urn:cts:greekLit:tlg0059.tlg036.perseus-grc2:1...
#
#                                          loc  seq  \
# 77440  urn:cts:greekLit:tlg0059.tlg036:1.309    0
#
#                                                     text              cites  \
# 77440  Πλάτων Διονυσίῳ εὖ πράττειν.διατρίψας ἐγὼ παρʼ...  [letter, section]
#
#        group lang    title  translation wlang                             work
# 77440  Plato  grc  Letters        False   grc  urn:cts:greekLit:tlg0059.tlg036

# %% [markdown]
# # Get Laws

# %%
plato_laws = perseus_df.loc[perseus_df["work"]=="urn:cts:greekLit:tlg0059.tlg034"]

# %%
plato_laws.shape
# Out:
# (654, 12)

# %%
plato_laws.head()
# Out:
#                                                book  \
# 76786  urn:cts:greekLit:tlg0059.tlg034.perseus-grc2
# 76787  urn:cts:greekLit:tlg0059.tlg034.perseus-grc2
# 76788  urn:cts:greekLit:tlg0059.tlg034.perseus-grc2
# 76789  urn:cts:greekLit:tlg0059.tlg034.perseus-grc2
# 76790  urn:cts:greekLit:tlg0059.tlg034.perseus-grc2
#
#                                                       id  \
# 76786  urn:cts:greekLit:tlg0059.tlg034.perseus-grc2:1...
# 76787  urn:cts:greekLit:tlg0059.tlg034.perseus-grc2:1...
# 76788  urn:cts:greekLit:tlg0059.tlg034.perseus-grc2:1...
# 76789  urn:cts:greekLit:tlg0059.tlg034.perseus-grc2:1...
# 76790  urn:cts:greekLit:tlg0059.tlg034.perseus-grc2:1...
#
#                                          loc  seq  \
# 76786  urn:cts:greekLit:tlg0059.tlg034:1.624    0
# 76787  urn:cts:greekLit:tlg0059.tlg034:1.625    1
# 76788  urn:cts:greekLit:tlg0059.tlg034:1.626    2
# 76789  urn:cts:greekLit:tlg0059.tlg034:1.627    3
# 76790  urn:cts:greekLit:tlg0059.tlg034:1.628    4
#
#                                                     text            cites  \
# 76786  ΑΘ. θεὸς ἤ τις ἀνθρώπων ὑμῖν, ὦ ξένοι, εἴληφε ...  [book, section]
# 76787  ΚΛ. λέγεται γὰρ οὕτω παρʼ ἡμῖν· καὶ δὴ καὶ τὸν...  [book, section]
# 76788  ΚΛ. εἰ δὴ πολέμου γε ὄντος φυλακῆς ἕνεκα δεῖ σ...  [book, section]
# 76789  ΑΘ. πάλιν τοίνυν τὸν λόγον ἀναστρέψωμεν. ἐπειδ...  [book, section]
# 76790  ΑΘ. τρίτον δέ που δικαστὴν πρὸς ἀρετὴν εἴπωμεν...  [book, section]
#
#        group lang title  translation wlang                             work
# 76786  Plato  grc  Laws        False   grc  urn:cts:greekLit:tlg0059.tlg034
# 76787  Plato  grc  Laws        False   grc  urn:cts:greekLit:tlg0059.tlg034
# 76788  Plato  grc  Laws        False   grc  urn:cts:greekLit:tlg0059.tlg034
# 76789  Plato  grc  Laws        False   grc  urn:cts:greekLit:tlg0059.tlg034
# 76790  Plato  grc  Laws        False   grc  urn:cts:greekLit:tlg0059.tlg034

# %%
laws_el = plato_laws.loc[plato_laws["lang"]=="grc"]

# %%
laws_el.shape
# Out:
# (327, 12)

# %%
laws_el_txt = laws_el["text"]

# %%
len(laws_el_txt)
# Out:
# 327

# %%
def write_file(input_lst, name_out):
    filename = name_out
    with open(filename, 'w') as file:
        for sentence in input_lst:
            file.write(f"{sentence}\n")

# %%
path_out = "/home/craig.car/repos/chiron/chironata/code/source_texts/plato_5_1852"
write_file(laws_el_txt, path_out)

# %% [markdown]
# # Get text with chapter idx

# %%
def concatenate_txt(txt_series):
    '''
    Converts to str (in case of NaN present as float) and concatenates rows 
    into one continuous string
    '''
    # convert all rows to string
    txt_series = txt_series.apply(str)
    # join into a single string
    return ' '.join(txt_series)

def get_perseus_txt_by_book(df, cts_tag, num_books):
    '''
    Extract Perseus text in df by book
    '''
    txt_by_book = []
    idx2book_name = {}
    idx_counter = 0
    for book_idx in range(1, num_books+1):
        loc_tag = cts_tag + str(book_idx)
        book_text = concatenate_txt(df[df['loc'].str.startswith(loc_tag)]['text'].replace('\n',' ', regex=True))
        txt_by_book.append(book_text)
        # add to dict. chap name format: "booknum"
        book_name = str(book_idx)
        idx2book_name[idx_counter] = book_name
        idx_counter += 1
    return txt_by_book, idx2book_name

# %%
grk_txt_by_chapter = []
grk_chap_idx_2_chap_name = {}
idx_counter = 0

for book_idx in range(1, 13):
    number_chapters = book_to_number_chaps[book_idx] + 1
    book_txt_by_chapter = []
    for chapter_num in range(1, number_chapters):
        loc_tag = "urn:cts:greekLit:tlg0003.tlg001:" + str(book_idx) + "." + str(chapter_num) + "."
        chapter_text = concatenate_txt(thuc_grc_df[thuc_grc_df['loc'].str.startswith(loc_tag)]['text'].replace('\n',' ', regex=True))
        book_txt_by_chapter.append(chapter_text)
        # add to dict. chap name format: "booknum,chapnum"
        chapter_name = str(book_idx) + "," + str(chapter_num)
        grk_chap_idx_2_chap_name[idx_counter] = chapter_name
        idx_counter += 1
    # add chapters to full text list
    grk_txt_by_chapter.extend(book_txt_by_chapter)

# %%
cts_tag_ = "urn:cts:greekLit:tlg0059.tlg034:"
lucretius_by_book, lucretius_sent2book_name = get_perseus_txt_by_book(lucretius_lat, cts_tag_, 12)
len(lucretius_by_book)
